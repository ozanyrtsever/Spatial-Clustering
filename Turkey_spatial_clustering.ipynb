# %%
# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pysal as ps
import geopandas as gpd
from sklearn import cluster
from sklearn.preprocessing import scale
from libpysal.weights import Queen

import libpysal
from libpysal import examples
import os
import region as rg
from pysal.viz.splot.libpysal import plot_spatial_weights
from libpysal.weights import Queen, Rook
from region.max_p_regions.heuristics import MaxPRegionsHeu
from region.p_regions.azp import AZPBasicTabu
import math


sns.set(style="whitegrid")
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %%
abb_link = 'C:\\Users\\user\\Desktop\\Arastirma Gorevi\\kodlar\\data_phyton\\data_codes.csv'
zc_link = 'C:\\Users\\user\\Desktop\\Arastirma Gorevi\\kodlar\\data_phyton\\lvl1-TR.geojson'

# %%
lst=pd.read_csv(abb_link)

# %%
zc = gpd.read_file(zc_link)  

zc.plot(color='red');
zc
# Out:
#          Name description timestamp  zipcode begin   end altitudeMode  \
# 0   Çanakkale          Il      None        1  None  None         None
# 1     Çankiri          Il      None        2  None  None         None
# 2       Çorum          Il      None        3  None  None         None
# 3       Adana          Il      None        4  None  None         None
# 4    Adiyaman          Il      None        5  None  None         None
# ..        ...         ...       ...      ...   ...   ...          ...
# 76       Usak          Il      None       77  None  None         None
# 77        Van          Il      None       78  None  None         None
# 78     Yalova          Il      None       79  None  None         None
# 79     Yozgat          Il      None       80  None  None         None
# 80  Zinguldak          Il      None       81  None  None         None
#
#     tessellate  extrude  visibility drawOrder  icon  \
# 0           -1        0           1      None  None
# 1           -1        0           1      None  None
# 2           -1        0           1      None  None
# 3           -1        0           1      None  None
# 4           -1        0           1      None  None
# ..         ...      ...         ...       ...   ...
# 76          -1        0           1      None  None
# 77          -1        0           1      None  None
# 78          -1        0           1      None  None
# 79          -1        0           1      None  None
# 80          -1        0           1      None  None
#
#                                              geometry
# 0   MULTIPOLYGON (((26.05347 39.84736, 26.05347 39...
# 1   MULTIPOLYGON (((33.78607 40.96249, 33.78677 40...
# 2   MULTIPOLYGON (((34.81906 41.20172, 34.84486 41...
# 3   MULTIPOLYGON (((35.27903 36.64069, 35.27903 36...
# 4   MULTIPOLYGON (((38.65534 38.09172, 38.66739 38...
# ..                                                ...
# 76  MULTIPOLYGON (((29.89273 38.77788, 29.89274 38...
# 77  MULTIPOLYGON (((43.34184 39.39789, 43.35878 39...
# 78  MULTIPOLYGON (((29.39486 40.70208, 29.39486 40...
# 79  MULTIPOLYGON (((35.34320 40.21666, 35.35103 40...
# 80  MULTIPOLYGON (((32.02097 41.56292, 32.02201 41...
#
# [81 rows x 13 columns]

# %%
price=[i for i in lst if 'price-' in i]
price
# Out:
# ['price-1',
#  'price-2',
#  'price-3',
#  'price-4',
#  'price-5',
#  'price-6',
#  'price-7',
#  'price-8',
#  'price-9',
#  'price-10',
#  'price-11',
#  'price-12',
#  'price-13',
#  'price-14',
#  'price-15',
#  'price-16',
#  'price-17',
#  'price-18',
#  'price-19',
#  'price-20',
#  'price-21',
#  'price-22',
#  'price-23',
#  'price-24']

# %%
daily_price = lst.mean(axis=1)

lst['daily_price']=daily_price

daily_price=[i for i in lst if 'daily_price' in i]
daily_price

rt_av = lst.groupby('zipcode')[price]\
.mean()

rt_av
# Out:
#            price-1    price-2    price-3    price-4    price-5    price-6  \
# zipcode
# 1        33.253990  43.677734  45.336132  45.159160  15.231617  15.774555
# 2        14.821420  14.709612  14.606618  13.942567  15.732105  16.335903
# 3        15.186857  14.875222  14.733469  13.932967  16.740344  17.466745
# 4        16.481372  17.901409  18.062152  17.650404  14.234502  14.656190
# 5        13.545599  13.642769  13.586999  13.224634  13.429482  13.753278
# ...            ...        ...        ...        ...        ...        ...
# 77       28.219204  35.833110  37.022632  36.736893  15.199153  15.738143
# 78       13.342889  13.339914  13.267607  12.905505  13.395826  13.715529
# 79       39.192057  52.931191  55.142844  55.094669  15.266311  15.813468
# 80       14.746925  14.327742  14.169892  13.409210  16.393790  17.078050
# 81       19.553400  22.193015  22.550631  22.028336  15.487149  16.061159
#
#            price-7    price-8    price-9   price-10  ...   price-15  \
# zipcode                                              ...
# 1        41.471990  50.796176  51.982244  34.615021  ...  26.757819
# 2        16.328413  22.272887  25.366922  24.588094  ...  28.581896
# 3        16.889696  24.154059  27.942614  27.379035  ...  32.158619
# 4        18.503141  22.732694  24.525073  22.009012  ...  23.073222
# 5        14.443932  16.899560  18.320669  19.111917  ...  20.103808
# ...            ...        ...        ...        ...  ...        ...
# 77       34.593685  42.764255  44.280338  28.159987  ...  26.637485
# 78       14.165002  16.548583  17.968019  18.923505  ...  19.995827
# 79       49.584098  60.263707  60.997964  38.996990  ...  26.886381
# 80       16.267481  22.994836  26.570201  26.495204  ...  30.917578
# 81       22.776048  29.441559  31.895812  23.362090  ...  27.697642
#
#           price-16   price-17   price-18   price-19   price-20   price-21  \
# zipcode
# 1        25.007249  24.529812  24.254970  15.709353  14.660958  26.350309
# 2        26.466839  25.939923  25.634393  15.709353  14.660958  14.168674
# 3        29.407201  28.780610  28.413259  15.709353  14.660958  14.331221
# 4        22.099327  21.720467  21.506764  15.709353  14.660958  15.610388
# 5        19.751617  19.452343  19.288000  15.709353  14.660958  14.762111
# ...            ...        ...        ...        ...        ...        ...
# 77       24.912572  24.438344  24.165493  15.709353  14.660958  19.505837
# 78       19.653466  19.357518  19.195240  15.709353  14.660958  14.654343
# 79       25.108428  24.627561  24.350592  15.709353  14.660958  30.961046
# 80       28.396536  27.804205  27.458103  15.709353  14.660958  14.356447
# 81       25.752464  25.249765  24.959255  15.709353  14.660958  13.540442
#
#           price-22   price-23   price-24
# zipcode
# 1        32.186581  32.900190  14.003365
# 2        20.819550  22.002568  14.003365
# 3        22.831889  24.337175  14.003365
# 4        19.527870  20.189729  14.003365
# 5        17.196569  17.619247  14.003365
# ...            ...        ...        ...
# 77       25.224748  26.100566  14.003365
# 78       17.026188  17.440692  14.003365
# 79       36.899889  37.508376  14.003365
# 80       22.221987  23.614456  14.003365
# 81       19.736926  20.856504  14.003365
#
# [81 rows x 24 columns]

# %%
zrt = zc[['geometry','zipcode']].join(rt_av,on='zipcode')\
                                 .dropna()
zrt.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 81 entries, 0 to 80
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  81 non-null     geometry
#  1   zipcode   81 non-null     int64
#  2   price-1   81 non-null     float64
#  3   price-2   81 non-null     float64
#  4   price-3   81 non-null     float64
#  5   price-4   81 non-null     float64
#  6   price-5   81 non-null     float64
#  7   price-6   81 non-null     float64
#  8   price-7   81 non-null     float64
#  9   price-8   81 non-null     float64
#  10  price-9   81 non-null     float64
#  11  price-10  81 non-null     float64
#  12  price-11  81 non-null     float64
#  13  price-12  81 non-null     float64
#  14  price-13  81 non-null     float64
#  15  price-14  81 non-null     float64
#  16  price-15  81 non-null     float64
#  17  price-16  81 non-null     float64
#  18  price-17  81 non-null     float64
#  19  price-18  81 non-null     float64
#  20  price-19  81 non-null     float64
#  21  price-20  81 non-null     float64
#  22  price-21  81 non-null     float64
#  23  price-22  81 non-null     float64
#  24  price-23  81 non-null     float64
#  25  price-24  81 non-null     float64
# dtypes: float64(24), geometry(1), int64(1)
# memory usage: 17.1 KB

# %%
zrt.to_file('tnp')
gdf=gpd.read_file('C:\\Users\\user\\Desktop\\Arastirma Gorevi\\tnp\\tnp.shp')
w_queen=Queen.from_dataframe(gdf)
w_rook=Rook.from_dataframe(gdf)

# %%
daily_data = lst.groupby('zipcode')[daily_price]\
.mean()

thr_=0.15*daily_data.sum()

thr=math.ceil(thr_)
thr
# Out:
# 285

# %%
z = zrt.drop(['geometry', 'zipcode'], axis=1).values

# %%
model_q = MaxPRegionsHeu(random_state=1)
model_q.fit_from_w(w_queen,z,daily_data.values[:, None], thr)

# %%
model_r =MaxPRegionsHeu(random_state=1)
model_r.fit_from_w(w_rook,z,daily_data.values[:,None],thr)

# %%
gdf.plot(column = model_q.labels_, categorical = True, figsize = (10, 10), legend = True)

# %%
gdf.plot(column = model_r.labels_, categorical = True, figsize = (10, 10), legend = True)
